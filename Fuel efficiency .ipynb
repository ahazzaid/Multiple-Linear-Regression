# %%
# Fuel efficiency using multiple linear regreession

import pandas as pd

# %%
dataSet = pd.read_csv("fuel_efficiency.csv")

# %%
dataSet
# Out:
#    Trip_ID  Avg_Speed  Distance  Sudden_Accelerations  Hard_Brakes Road_Type  \
# 0        1         45        15                     2            1   Highway
# 1        2         25         5                     8            6      City
# 2        3         60        30                     1            0   Highway
# 3        4         35        10                     5            4     Rural
# 4        5         50        20                     3            2   Highway
# 5        6         20         3                    10            8      City
# 6        7         55        25                     0            1   Highway
# 7        8         40        12                     4            3     Rural
# 8        9         30         8                     7            5      City
# 9       10         65        35                     1            0   Highway
#
#    Engine_Load  Tire_Pressure  Outside_Temp  Fuel_Efficiency
# 0           65             32            75             28.5
# ...

# %%
dataSet = pd.get_dummies(dataSet, drop_first=True) # to handle the nominal data (state coloum)

# %%
dataSet # verifying
# Out:
#    Trip_ID  Avg_Speed  Distance  Sudden_Accelerations  Hard_Brakes  \
# 0        1         45        15                     2            1
# 1        2         25         5                     8            6
# 2        3         60        30                     1            0
# 3        4         35        10                     5            4
# 4        5         50        20                     3            2
# 5        6         20         3                    10            8
# 6        7         55        25                     0            1
# 7        8         40        12                     4            3
# 8        9         30         8                     7            5
# 9       10         65        35                     1            0
#
#    Engine_Load  Tire_Pressure  Outside_Temp  Fuel_Efficiency  \
# 0           65             32            75             28.5
# 1           85             28            68             18.2
# ...

# %%
dataSet.columns
# Out:
# Index(['Trip_ID', 'Avg_Speed', 'Distance', 'Sudden_Accelerations',
#        'Hard_Brakes', 'Engine_Load', 'Tire_Pressure', 'Outside_Temp',
#        'Fuel_Efficiency', 'Road_Type_Highway', 'Road_Type_Rural'],
#       dtype='object')

# %%
independent = dataSet[['Trip_ID', 'Avg_Speed', 'Distance', 'Sudden_Accelerations', 'Hard_Brakes', 'Engine_Load', 'Tire_Pressure', 'Outside_Temp', 'Road_Type_Highway', 'Road_Type_Rural']]

# %%
dependent = dataSet[['Fuel_Efficiency']]

# %%
independent
# Out:
#    Trip_ID  Avg_Speed  Distance  Sudden_Accelerations  Hard_Brakes  \
# 0        1         45        15                     2            1
# 1        2         25         5                     8            6
# 2        3         60        30                     1            0
# 3        4         35        10                     5            4
# 4        5         50        20                     3            2
# 5        6         20         3                    10            8
# 6        7         55        25                     0            1
# 7        8         40        12                     4            3
# 8        9         30         8                     7            5
# 9       10         65        35                     1            0
#
#    Engine_Load  Tire_Pressure  Outside_Temp  Road_Type_Highway  \
# 0           65             32            75               True
# 1           85             28            68              False
# ...

# %%
dependent
# Out:
#    Fuel_Efficiency
# 0             28.5
# 1             18.2
# 2             34.0
# 3             22.1
# 4             27.8
# 5             15.4
# 6             32.5
# 7             24.3
# 8             17.9
# 9             36.7

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[-0.18844776,  0.35911433,  0.24876672, -0.13923716, -0.11852576,
#         -0.03773282,  0.12741084, -0.35949898,  0.26573966, -0.4069984 ]])

# %%
bais=regressor.intercept_
bais
# Out:
# array([34.26597293])

# %%
y_pred=regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[35.61474022],
#        [19.92680094],
#        [29.38810106]])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)

# %%
r_score
# Out:
# 0.9299597658872261

# %%
import pickle
filename="finalized_model_linear.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
independent
# Out:
#    Trip_ID  Avg_Speed  Distance  Sudden_Accelerations  Hard_Brakes  \
# 0        1         45        15                     2            1
# 1        2         25         5                     8            6
# 2        3         60        30                     1            0
# 3        4         35        10                     5            4
# 4        5         50        20                     3            2
# 5        6         20         3                    10            8
# 6        7         55        25                     0            1
# 7        8         40        12                     4            3
# 8        9         30         8                     7            5
# 9       10         65        35                     1            0
#
#    Engine_Load  Tire_Pressure  Outside_Temp  Road_Type_Highway  \
# 0           65             32            75               True
# 1           85             28            68              False
# ...

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[10,65,35,1,0,50,36,85,1,0]])
result
# Out:
# C:\Users\ahazz\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[36.7]])
